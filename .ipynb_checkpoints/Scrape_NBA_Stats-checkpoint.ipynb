# %%
#widen display
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:95% !important; }</style>"))
# Out:
# <style>.container { width:95% !important; }</style>

# %%
from bs4 import BeautifulSoup
import pandas as pd
from splinter import Browser
from splinter.exceptions import ElementDoesNotExist
import time

# %%
nba_stats_base_url = 'https://stats.nba.com/teams/traditional/?sort=TEAM_NAME&dir=-1&SeasonType=Regular%20Season'

# %%
seasons = ['&Season=2017-18', '&Season=2016-17', '&Season=2015-16', '&Season=2014-15', '&Season=2013-14'
          , '&Season=2012-13', '&Season=2011-12', '&Season=2010-11', '&Season=2009-10', '&Season=2008-09', '&Season=2007-08'
          , '&Season=2006-07', '&Season=2005-06', '&Season=2004-05', '&Season=2003-04', '&Season=2002-03', '&Season=2001-02'
          , '&Season=2000-01']

# %%
executable_path = {'executable_path': 'chromedriver.exe'}
browser = Browser('chrome', **executable_path, headless=False)

# %%
#Vist first season to create dataframe - don't feel like manually creating the dataframe columns :)
browser.visit(nba_stats_base_url)
time.sleep(3)

html = browser.html
stats_html = BeautifulSoup(html, 'html.parser')

tables = pd.read_html(str(stats_html))

all_seasons_stats_df = tables[0]

all_seasons_stats_df.insert(54, "SEASON", "2018-19", True)

# %%
all_seasons_stats_df.head()
# Out:
#    Unnamed: 0               TEAM  GP   W   L   WIN%   MIN    PTS   FGM   FGA  \
# 0         NaN      Atlanta Hawks  82  29  53  0.354  48.4  113.3  41.4  91.8
# 1         NaN     Boston Celtics  82  49  33  0.598  48.2  112.4  42.1  90.5
# 2         NaN      Brooklyn Nets  82  42  40  0.512  48.7  112.2  40.3  89.7
# 3         NaN  Charlotte Hornets  82  39  43  0.476  48.4  110.7  40.2  89.8
# 4         NaN      Chicago Bulls  82  22  60  0.268  48.5  104.9  39.8  87.9
#
#    ...  REB RANK  AST RANK  TOV RANK  STL RANK  BLK RANK  BLKA RANK  PF RANK  \
# 0  ...       NaN       NaN       NaN       NaN       NaN        NaN      NaN
# 1  ...       NaN       NaN       NaN       NaN       NaN        NaN      NaN
# 2  ...       NaN       NaN       NaN       NaN       NaN        NaN      NaN
# 3  ...       NaN       NaN       NaN       NaN       NaN        NaN      NaN
# 4  ...       NaN       NaN       NaN       NaN       NaN        NaN      NaN
#
#    PFD RANK  +/- RANK   SEASON
# 0       NaN       NaN  2018-19
# 1       NaN       NaN  2018-19
# 2       NaN       NaN  2018-19
# 3       NaN       NaN  2018-19
# 4       NaN       NaN  2018-19
#
# [5 rows x 55 columns]

# %%
#loop through rest of seasons and append dataframes
for season in seasons:
    nba_season_stats_url = nba_stats_base_url + season

    browser.visit(nba_season_stats_url)
    time.sleep(3)
    
    html = browser.html
    stats_html = BeautifulSoup(html, 'html.parser')
    
    tables = pd.read_html(str(stats_html))
    
    this_season_stats_df = tables[0]
    
    #add the season for this set of stats
    this_season_stats_df.insert(54, "SEASON", season.strip('&Season='), True) 
    
    all_seasons_stats_df = all_seasons_stats_df.append(this_season_stats_df, ignore_index=True)

# %%
#drop unwanted columns
all_seasons_stats_df.drop(all_seasons_stats_df.iloc[:, 28:54], inplace = True, axis = 1)
all_seasons_stats_df.drop(all_seasons_stats_df.columns[0], inplace = True, axis=1)

# %%
all_seasons_stats_df.head()
# Out:
#                           team  games_played  wins  losses  win_percentage  \
# teamstatspk
# 0                Atlanta Hawks            82    29      53           0.354
# 1               Boston Celtics            82    49      33           0.598
# 2                Brooklyn Nets            82    42      40           0.512
# 3            Charlotte Hornets            82    39      43           0.476
# 4                Chicago Bulls            82    22      60           0.268
#
#              minutes  points  field_goals_made  field_goals_attempted  \
# teamstatspk
# 0               48.4   113.3              41.4                   91.8
# 1               48.2   112.4              42.1                   90.5
# 2               48.7   112.2              40.3                   89.7
# 3               48.4   110.7              40.2                   89.8
# 4               48.5   104.9              39.8                   87.9
#
#              field_goal_percentage  ...  rebounds  assists  turnovers  steals  \
# teamstatspk                         ...
# 0                             45.1  ...      46.1     25.8       17.0     8.2
# 1                             46.5  ...      44.5     26.3       12.8     8.6
# 2                             44.9  ...      46.6     23.8       15.1     6.6
# 3                             44.8  ...      43.8     23.2       12.2     7.2
# 4                             45.3  ...      42.9     21.9       14.1     7.4
#
#              blocks  blocks_attempted  personal_fouls  personal_fouls_drawn  \
# teamstatspk
# 0               5.1               5.5            23.6                  22.2
# 1               5.3               3.9            20.4                  19.5
# 2               4.1               5.3            21.5                  22.0
# 3               4.9               6.0            18.9                  20.6
# 4               4.3               5.8            20.3                  18.7
#
#              plus_minus   season
# teamstatspk
# 0                  -6.0  2018-19
# 1                   4.4  2018-19
# 2                  -0.1  2018-19
# 3                  -1.1  2018-19
# 4                  -8.4  2018-19
#
# [5 rows x 28 columns]

# %%
all_seasons_stats_df = all_seasons_stats_df.rename(columns={'TEAM':'team','GP':'games_played','W':'wins','L':'losses','WIN%':'win_percentage','MIN':'minutes','PTS':'points','FGM':'field_goals_made','FGA':'field_goals_attempted','FG%':'field_goal_percentage','3PM':'three_pointers_made','3PA':'three_pointers_attempted','3P%':'three_point_percentage','FTM':'free_throws_made','FTA':'free_throw_attempted','FT%':'free_throw_percentage','OREB':'offensive_rebounds','DREB':'defensive_rebounds','REB':'rebounds','AST':'assists','TOV':'turnovers','STL':'steals','BLK':'blocks','BLKA':'blocks_attempted','PF':'personal_fouls','PFD':'personal_fouls_drawn','+/-':'plus_minus','SEASON':'season'})

# %%
all_seasons_stats_df.index.name = 'teamstatspk'

# %%
all_seasons_stats_df.to_csv('data/nba_team_stats_00_to_18.csv')

# %%
all_seasons_stats_df.head()
# Out:
#                           team  games_played  wins  losses  win_percentage  \
# teamstatspk
# 0                Atlanta Hawks            82    29      53           0.354
# 1               Boston Celtics            82    49      33           0.598
# 2                Brooklyn Nets            82    42      40           0.512
# 3            Charlotte Hornets            82    39      43           0.476
# 4                Chicago Bulls            82    22      60           0.268
#
#              minutes  points  field_goals_made  field_goals_attempted  \
# teamstatspk
# 0               48.4   113.3              41.4                   91.8
# 1               48.2   112.4              42.1                   90.5
# 2               48.7   112.2              40.3                   89.7
# 3               48.4   110.7              40.2                   89.8
# 4               48.5   104.9              39.8                   87.9
#
#              field_goal_percentage  ...  rebounds  assists  turnovers  steals  \
# teamstatspk                         ...
# 0                             45.1  ...      46.1     25.8       17.0     8.2
# 1                             46.5  ...      44.5     26.3       12.8     8.6
# 2                             44.9  ...      46.6     23.8       15.1     6.6
# 3                             44.8  ...      43.8     23.2       12.2     7.2
# 4                             45.3  ...      42.9     21.9       14.1     7.4
#
#              blocks  blocks_attempted  personal_fouls  personal_fouls_drawn  \
# teamstatspk
# 0               5.1               5.5            23.6                  22.2
# 1               5.3               3.9            20.4                  19.5
# 2               4.1               5.3            21.5                  22.0
# 3               4.9               6.0            18.9                  20.6
# 4               4.3               5.8            20.3                  18.7
#
#              plus_minus   season
# teamstatspk
# 0                  -6.0  2018-19
# 1                   4.4  2018-19
# 2                  -0.1  2018-19
# 3                  -1.1  2018-19
# 4                  -8.4  2018-19
#
# [5 rows x 28 columns]
